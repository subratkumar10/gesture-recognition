# %%
from dis import dis
from tkinter.tix import AUTO
from requests import head
import torch
import config
import os
from glob import glob
from shutil import copyfile
import pandas as pd
import re
import numpy as np
from math import sqrt
import math
import tensorflow as tf
from keras import regularizers
from tensorflow.keras import Model, Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
from re import X
import numpy as np
import torch
import pandas as pd
from torch.nn.utils.rnn import pack_padded_sequence
from torch.utils.data import DataLoader
from CustomDataset import CustomRawDataset
from model_dispatcher import dispatch_model
# from model_dispatcher_cnn import dispatch_model
import config
from torch import nn
import os
from glob import glob
from torch.optim import Adam, SGD
from torch.optim.lr_scheduler import ReduceLROnPlateau
from datetime import date, timedelta, datetime
import time
import random
from torch.utils.tensorboard import SummaryWriter
from CustomDataset import custom_collate_fn
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation,TimeDistributed
from tensorflow.keras.layers import Bidirectional, GlobalMaxPool1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_20124\4271784750.py:2: DeprecationWarning: The Tix Tk extension is unmaintained, and the tkinter.tix wrapper module is deprecated in favor of tkinter.ttk
#   from tkinter.tix import AUTO

# %%
raw_angle_files_1 = glob(os.path.join("D:\Research_Project\My_project_22\input\preprocessed", "*", "*.csv"))
# print(raw_angle_files_1)
all_filenames = [i for i in raw_angle_files_1]
df = pd.concat(map(pd.read_csv, all_filenames),ignore_index=True)
data=df
data.to_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\merged.csv",index=False)
#df=pd.read_csv(r"D:\Research_Project\My_project_22\FEATURES_EXTRACTED\DISTANCES\both_hand_frontup_left_leg_frontup\aatish_both_hand_frontup_left_leg_frontup_trial1_interpolated.csv")
   
# data=df
# print(data.shape)
# target=data['54']
# data=data.drop(['54'],axis=1)
# # data.head()
# print(data.shape)
# AutoEncoder(data)
# data['12']=target
# print(data.shape)

# %%
data=pd.read_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\merged_modified.csv")
data.head()
target=data['target']
data=data.drop(['target'],axis=1)
# data.head()
# print(data.shape)
# AutoEncoder(data)
# data['12']=target
# print(data.shape)
print(data.shape)
print(target.shape)
# Out:
# (12260, 166)
# (12260,)

# %%
from sklearn.ensemble import RandomForestClassifier
# create the random forest with your hyperparameters.
model = RandomForestClassifier(n_estimators=342)

# fit the model to start training.

model.fit(data, target)

# get the importance of the resulting features.
importances = model.feature_importances_

# create a data frame for visualization.

final_df = pd.DataFrame({"Features": pd.DataFrame(data).columns, "Importances":importances})
final_df.set_index("Importances")

# sort in ascending order to better visualization.
final_df =final_df.sort_values('Importances')
plt.figure(figsize=(30,25))

# plot the feature inportances in bars.
# Out:
# <AxesSubplot:>

# %%
print(final_df)
plt.figure(figsize=(20,20))
plt.xlabel('Features',size=20)
plt.ylabel('Importances',size=20)
plt.bar(final_df['Features'],final_df['Importances'],label="Importance")
# Out:
#                 Features  Importances
# 78            dist_22_21     0.000933
# 98            dist_20_24     0.001492
# 77            dist_20_21     0.002018
# 23             dist_24_1     0.002104
# 68            dist_20_23     0.002292
# ..                   ...          ...
# 163                   12     0.013753
# 161                   10     0.014384
# 122  centroid_19_16_15_a     0.014447
# 164                   13     0.015944
# 160                    9     0.016590
#
# [166 rows x 2 columns]
# <BarContainer object of 166 artists>

# %%
x=list(final_df['Features'])
y=list(final_df['Importances'])
y1=[]
x1=[]
sorted_id=[]
for i in range(-26,0):
    x[i]=str(x[i])
    sorted_id.append(x[i])
    y1.append(y[i])
x1=sorted_id

data=data[sorted_id] 
data.head()
data.columns
# Out:
# Index(['centroid_20_0_23_a', 'centroid_19_16_15_c', 'dist_21_23',
#        'centroid_15_12_19_c', 'centroid_20_9_1_c', 'centroid_20_5_1_c',
#        'dist_23_21', 'dist_4_1', 'centroid_3_23_16_a', 'centroid_0_13_17_c',
#        'centroid_9_23_16_a', 'dist_22_23', 'dist_7_11', '5', 'dist_6_11',
#        'centroid_20_9_1_a', 'centroid_20_5_1_a', 'centroid_0_14_18_c',
#        'centroid_0_15_19_a', 'centroid_0_14_18_a', 'centroid_15_12_19_a', '12',
#        '10', 'centroid_19_16_15_a', '13', '9'],
#       dtype='object')

# %%
# print(final_df)
plt.figure(figsize=(30,30))
plt.xlabel('Features',size=20)
plt.ylabel('Importances',size=20)
plt.bar(x1,y1,label="Importance")
plt.xticks(x1,rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x1dd84bc4f10>,
#   <matplotlib.axis.XTick at 0x1dd84bc4ee0>,
#   <matplotlib.axis.XTick at 0x1dd84bc4be0>,
#   <matplotlib.axis.XTick at 0x1dd84c35690>,
#   <matplotlib.axis.XTick at 0x1dd84c35de0>,
#   <matplotlib.axis.XTick at 0x1dd84c36530>,
#   <matplotlib.axis.XTick at 0x1dd84c36170>,
#   <matplotlib.axis.XTick at 0x1dd84c36b60>,
#   <matplotlib.axis.XTick at 0x1dd84c372b0>,
#   <matplotlib.axis.XTick at 0x1dd84c37a00>,
#   <matplotlib.axis.XTick at 0x1dd84c54190>,
#   <matplotlib.axis.XTick at 0x1dd84c548e0>,
#   <matplotlib.axis.XTick at 0x1dd84c37df0>,
#   <matplotlib.axis.XTick at 0x1dd84c36e00>,
#   <matplotlib.axis.XTick at 0x1dd84c54940>,
#   <matplotlib.axis.XTick at 0x1dd84c555d0>,
#   <matplotlib.axis.XTick at 0x1dd84c55d20>,
#   <matplotlib.axis.XTick at 0x1dd84c56470>,
#   <matplotlib.axis.XTick at 0x1dd84c56bc0>,
#   <matplotlib.axis.XTick at 0x1dd84c37370>,
#   <matplotlib.axis.XTick at 0x1dd84c56200>,
#   <matplotlib.axis.XTick at 0x1dd84c54520>,
#   <matplotlib.axis.XTick at 0x1dd84c57820>,
#   <matplotlib.axis.XTick at 0x1dd84c70040>,
#   <matplotlib.axis.XTick at 0x1dd84c70700>,
#   <matplotlib.axis.XTick at 0x1dd84c70e50>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# len1=data.shape[1]
# l1=list(range(0,len1))
# l2=[]
# for i in l1:
#     i=str(i)
#     l2.append(i)
# l1=l2
    
# data.columns=l1
# data.head()
# data['26']=target
# data.head()
data['target']=target
data.head()
# Out:
#    centroid_20_0_23_a  centroid_19_16_15_c  dist_21_23  centroid_15_12_19_c  \
# 0            0.446287             2.259500    0.409982             2.261033
# 1            0.449207             2.266967    0.404327             2.268333
# 2            0.451327             2.269333    0.405290             2.270667
# 3            0.452303             2.269467    0.407274             2.270800
# 4            0.451847             2.269467    0.408114             2.270833
#
#    centroid_20_9_1_c  centroid_20_5_1_c  dist_23_21  dist_4_1  \
# 0           2.216000           2.222067    0.409982  0.257537
# 1           2.224300           2.230433    0.404327  0.260437
# 2           2.227500           2.233733    0.405290  0.261410
# 3           2.228000           2.234267    0.407274  0.261484
# 4           2.228167           2.234367    0.408114  0.261522
#
#    centroid_3_23_16_a  centroid_0_13_17_c  ...  centroid_0_14_18_c  \
# 0            0.483507            2.270467  ...            2.316167
# 1            0.482320            2.277767  ...            2.317200
# 2            0.482950            2.280433  ...            2.317700
# 3            0.483680            2.280833  ...            2.317867
# 4            0.483077            2.280933  ...            2.317967
#
#    centroid_0_15_19_a  centroid_0_14_18_a  centroid_15_12_19_a        12  \
# 0            0.373833            0.375580             0.346157  0.113375
# 1            0.378393            0.379317             0.350710  0.088090
# 2            0.379813            0.380610             0.352113  0.079567
# 3            0.379817            0.380717             0.352107  0.078291
# 4            0.379800            0.380730             0.352097  0.077394
#
#          10  centroid_19_16_15_a        13         9  target
# 0 -0.027582             0.397397  0.031990  0.162107       0
# 1 -0.009114             0.401893  0.029938  0.157114       0
# 2 -0.002401             0.403303  0.029953  0.156264       0
# 3 -0.001148             0.403313  0.030147  0.155941       0
# 4 -0.000888             0.403287  0.030157  0.155132       0
#
# [5 rows x 27 columns]

# %%
# len1=data.shape[1]
# l1=list(range(0,len1))
# l2=[]
# for i in l1:
#     i=str(i)
#     l2.append(i)
# l1=l2
    
# data.columns=l1
# data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.409982  0.380257  0.253687  2.261033  0.446287  0.483507  1.650141
# 1  0.404327  0.383360  0.252057  2.268333  0.449207  0.482320  1.632925
# 2  0.405290  0.384443  0.251537  2.270667  0.451327  0.482950  1.627664
# 3  0.407274  0.384600  0.251446  2.270800  0.452303  0.483680  1.626473
# 4  0.408114  0.384773  0.251438  2.270833  0.451847  0.483077  1.624955
#
#           7         8         9  ...        17        18        19        20  \
# 0  0.540860  2.222067  0.257537  ...  2.316167  0.113375  0.414414  0.346157
# 1  0.542580  2.230433  0.260437  ...  2.317200  0.088090  0.436329  0.350710
# 2  0.544257  2.233733  0.261410  ...  2.317700  0.079567  0.442395  0.352113
# 3  0.545180  2.234267  0.261484  ...  2.317867  0.078291  0.441379  0.352107
# 4  0.544767  2.234367  0.261522  ...  2.317967  0.077394  0.441859  0.352097
#
#          21        22        23        24        25  26
# 0 -0.027582  0.375580  0.397397  0.373833  0.031990   0
# 1 -0.009114  0.379317  0.401893  0.378393  0.029938   0
# 2 -0.002401  0.380610  0.403303  0.379813  0.029953   0
# 3 -0.001148  0.380717  0.403313  0.379817  0.030147   0
# 4 -0.000888  0.380730  0.403287  0.379800  0.030157   0
#
# [5 rows x 27 columns]

# %%
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :26], sequences[end_ix-1, 26:]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
data=pd.read_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\random_tree_classifier_extracted_modified.csv")
data=pd.get_dummies(data,columns=['target'])
data=data.to_numpy()
x,y=split_sequences(data,6)
print(y.shape)

# target=data['26']
# data=data.drop(['26'],axis=1)
x_train,x_test,y_train,y_test= train_test_split(x, y, test_size = 0.2)



# Model building
n_steps=6

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, 26), return_sequences=True))
model.add(LSTM(30, activation='relu'))
model.add(Dense(10,activation='softmax'))

model.summary()
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(x.shape)
history = model.fit(x_train, y_train,batch_size=config.BATCH_SIZE,epochs=100,validation_data=(x_test,y_test),verbose=1)
results = model.evaluate(x_test, y_test)
y_pred=model.predict(x_test)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# print(y_pred)
cf_matrix=confusion_matrix(y_test,y_pred)
print('Confusion matrix\n',cf_matrix)
print(classification_report(y_test,y_pred))
# Out:
# (12255, 10)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 50)             15400
#
#  lstm_1 (LSTM)               (None, 30)                9720
#
#  dense (Dense)               (None, 10)                310
#
# =================================================================
# Total params: 25,430
# Trainable params: 25,430
# Non-trainable params: 0
# _________________________________________________________________
# (12255, 6, 26)
# Epoch 1/100
# 154/154 [==============================] - 14s 70ms/step - loss: 2.2997 - accuracy: 0.2557 - val_loss: 1.7368 - val_accuracy: 0.3497
# Epoch 2/100
# 154/154 [==============================] - 13s 87ms/step - loss: 1.6016 - accuracy: 0.4253 - val_loss: 1.4708 - val_accuracy: 0.4529
# Epoch 3/100
# 154/154 [==============================] - 30s 191ms/step - loss: 1.3658 - accuracy: 0.4905 - val_loss: 1.3135 - val_accuracy: 0.5031
# Epoch 4/100
# 154/154 [==============================] - 10s 67ms/step - loss: 1.2558 - accuracy: 0.5181 - val_loss: 1.3984 - val_accuracy: 0.4990
# Epoch 5/100
# 154/154 [==============================] - 10s 63ms/step - loss: 1.2079 - accuracy: 0.5444 - val_loss: 1.2071 - val_accuracy: 0.5353
# Epoch 6/100
# 154/154 [==============================] - 9s 61ms/step - loss: 1.1925 - accuracy: 0.5610 - val_loss: 1.2241 - val_accuracy: 0.5312
# Epoch 7/100
# 154/154 [==============================] - 11s 74ms/step - loss: 1.1065 - accuracy: 0.5832 - val_loss: 1.1308 - val_accuracy: 0.5545
# Epoch 8/100
# 154/154 [==============================] - 9s 61ms/step - loss: 1.0675 - accuracy: 0.5928 - val_loss: 1.0747 - val_accuracy: 0.5826
# Epoch 9/100
# 154/154 [==============================] - 11s 69ms/step - loss: 1.0310 - accuracy: 0.6061 - val_loss: 1.1055 - val_accuracy: 0.5900
# Epoch 10/100
# 154/154 [==============================] - 11s 70ms/step - loss: 1.0234 - accuracy: 0.6092 - val_loss: 1.0542 - val_accuracy: 0.6055
# Epoch 11/100
# 154/154 [==============================] - 14s 90ms/step - loss: 0.9899 - accuracy: 0.6276 - val_loss: 1.2903 - val_accuracy: 0.5492
# Epoch 12/100
# 154/154 [==============================] - 12s 78ms/step - loss: 0.9638 - accuracy: 0.6360 - val_loss: 1.0191 - val_accuracy: 0.6149
# Epoch 13/100
# 154/154 [==============================] - 13s 87ms/step - loss: 0.9467 - accuracy: 0.6414 - val_loss: 1.0099 - val_accuracy: 0.6185
# Epoch 14/100
# 154/154 [==============================] - 14s 89ms/step - loss: 0.9161 - accuracy: 0.6521 - val_loss: 1.0068 - val_accuracy: 0.6034
# Epoch 15/100
# 154/154 [==============================] - 12s 78ms/step - loss: 0.8914 - accuracy: 0.6630 - val_loss: 0.9549 - val_accuracy: 0.6422
# Epoch 16/100
# 154/154 [==============================] - 12s 77ms/step - loss: 0.8429 - accuracy: 0.6786 - val_loss: 0.9070 - val_accuracy: 0.6463
# Epoch 17/100
# 154/154 [==============================] - 13s 84ms/step - loss: 0.8286 - accuracy: 0.6866 - val_loss: 0.9575 - val_accuracy: 0.6304
# Epoch 18/100
# 154/154 [==============================] - 16s 101ms/step - loss: 0.8063 - accuracy: 0.6937 - val_loss: 0.8370 - val_accuracy: 0.6789
# Epoch 19/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.7916 - accuracy: 0.7077 - val_loss: 0.9451 - val_accuracy: 0.6520
# Epoch 20/100
# 154/154 [==============================] - 14s 93ms/step - loss: 0.7783 - accuracy: 0.7091 - val_loss: 0.9267 - val_accuracy: 0.6626
# Epoch 21/100
# 154/154 [==============================] - 12s 81ms/step - loss: 0.7251 - accuracy: 0.7264 - val_loss: 0.7931 - val_accuracy: 0.7115
# Epoch 22/100
# 154/154 [==============================] - 11s 69ms/step - loss: 0.7026 - accuracy: 0.7347 - val_loss: 0.9301 - val_accuracy: 0.6512
# Epoch 23/100
# 154/154 [==============================] - 12s 78ms/step - loss: 0.6795 - accuracy: 0.7481 - val_loss: 0.7813 - val_accuracy: 0.7217
# Epoch 24/100
# 154/154 [==============================] - 14s 91ms/step - loss: 0.6844 - accuracy: 0.7441 - val_loss: 0.8000 - val_accuracy: 0.6977
# Epoch 25/100
# 154/154 [==============================] - 12s 78ms/step - loss: 0.6248 - accuracy: 0.7695 - val_loss: 0.7232 - val_accuracy: 0.7442
# Epoch 26/100
# 154/154 [==============================] - 13s 85ms/step - loss: 0.6389 - accuracy: 0.7633 - val_loss: 0.8410 - val_accuracy: 0.6887
# Epoch 27/100
# 154/154 [==============================] - 12s 76ms/step - loss: 0.6168 - accuracy: 0.7746 - val_loss: 0.6757 - val_accuracy: 0.7511
# Epoch 28/100
# 154/154 [==============================] - 12s 77ms/step - loss: 0.5737 - accuracy: 0.7888 - val_loss: 0.6852 - val_accuracy: 0.7597
# Epoch 29/100
# 154/154 [==============================] - 11s 72ms/step - loss: 0.5821 - accuracy: 0.7860 - val_loss: 0.6336 - val_accuracy: 0.7858
# Epoch 30/100
# 154/154 [==============================] - 10s 62ms/step - loss: 0.5829 - accuracy: 0.7898 - val_loss: 0.6584 - val_accuracy: 0.7678
# Epoch 31/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.5143 - accuracy: 0.8122 - val_loss: 0.5976 - val_accuracy: 0.7952
# Epoch 32/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.5004 - accuracy: 0.8178 - val_loss: 0.5769 - val_accuracy: 0.7915
# Epoch 33/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.4937 - accuracy: 0.8220 - val_loss: 0.5399 - val_accuracy: 0.8205
# Epoch 34/100
# 154/154 [==============================] - 11s 73ms/step - loss: 0.4929 - accuracy: 0.8209 - val_loss: 0.5865 - val_accuracy: 0.8021
# Epoch 35/100
# 154/154 [==============================] - 10s 65ms/step - loss: 0.5173 - accuracy: 0.8156 - val_loss: 0.6211 - val_accuracy: 0.7870
# Epoch 36/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.4326 - accuracy: 0.8456 - val_loss: 0.5229 - val_accuracy: 0.8176
# Epoch 37/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.4436 - accuracy: 0.8400 - val_loss: 0.6084 - val_accuracy: 0.7964
# Epoch 38/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.4135 - accuracy: 0.8581 - val_loss: 0.4889 - val_accuracy: 0.8319
# Epoch 39/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.3727 - accuracy: 0.8665 - val_loss: 0.5083 - val_accuracy: 0.8425
# Epoch 40/100
# 154/154 [==============================] - 10s 62ms/step - loss: 0.4007 - accuracy: 0.8572 - val_loss: 0.4880 - val_accuracy: 0.8482
# Epoch 41/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.3670 - accuracy: 0.8692 - val_loss: 0.4757 - val_accuracy: 0.8388
# Epoch 42/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.3406 - accuracy: 0.8806 - val_loss: 0.4405 - val_accuracy: 0.8596
# Epoch 43/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.3372 - accuracy: 0.8831 - val_loss: 0.4106 - val_accuracy: 0.8739
# Epoch 44/100
# 154/154 [==============================] - 14s 93ms/step - loss: 0.3512 - accuracy: 0.8768 - val_loss: 0.4289 - val_accuracy: 0.8645
# Epoch 45/100
# 154/154 [==============================] - 12s 79ms/step - loss: 0.2927 - accuracy: 0.9002 - val_loss: 0.3786 - val_accuracy: 0.8809
# Epoch 46/100
# 154/154 [==============================] - 11s 71ms/step - loss: 0.2985 - accuracy: 0.8957 - val_loss: 0.4937 - val_accuracy: 0.8458
# Epoch 47/100
# 154/154 [==============================] - 9s 61ms/step - loss: 0.3024 - accuracy: 0.8919 - val_loss: 0.6260 - val_accuracy: 0.7997
# Epoch 48/100
# 154/154 [==============================] - 9s 59ms/step - loss: 0.2877 - accuracy: 0.9003 - val_loss: 0.4799 - val_accuracy: 0.8584
# Epoch 49/100
# 154/154 [==============================] - 9s 60ms/step - loss: 0.2736 - accuracy: 0.9057 - val_loss: 0.3727 - val_accuracy: 0.8870
# Epoch 50/100
# 154/154 [==============================] - 11s 75ms/step - loss: 0.2577 - accuracy: 0.9137 - val_loss: 0.4195 - val_accuracy: 0.8756
# Epoch 51/100
# 154/154 [==============================] - 17s 109ms/step - loss: 0.2787 - accuracy: 0.9027 - val_loss: 0.4159 - val_accuracy: 0.8870
# Epoch 52/100
# 154/154 [==============================] - 14s 89ms/step - loss: 0.2151 - accuracy: 0.9276 - val_loss: 0.3588 - val_accuracy: 0.9000
# Epoch 53/100
# 154/154 [==============================] - 10s 66ms/step - loss: 0.2471 - accuracy: 0.9148 - val_loss: 0.4511 - val_accuracy: 0.8645
# Epoch 54/100
# 154/154 [==============================] - 9s 61ms/step - loss: 0.2236 - accuracy: 0.9247 - val_loss: 0.3161 - val_accuracy: 0.9115
# Epoch 55/100
# 154/154 [==============================] - 10s 63ms/step - loss: 0.2116 - accuracy: 0.9291 - val_loss: 0.3190 - val_accuracy: 0.9200
# Epoch 56/100
# 154/154 [==============================] - 10s 62ms/step - loss: 0.2127 - accuracy: 0.9290 - val_loss: 0.2901 - val_accuracy: 0.9237
# Epoch 57/100
# 154/154 [==============================] - 10s 63ms/step - loss: 0.2467 - accuracy: 0.9135 - val_loss: 0.3424 - val_accuracy: 0.9164
# Epoch 58/100
# 154/154 [==============================] - 10s 64ms/step - loss: 0.1677 - accuracy: 0.9444 - val_loss: 0.3538 - val_accuracy: 0.9045
# Epoch 59/100
# 154/154 [==============================] - 11s 71ms/step - loss: 0.2115 - accuracy: 0.9279 - val_loss: 0.3575 - val_accuracy: 0.9000
# Epoch 60/100
# 154/154 [==============================] - 11s 70ms/step - loss: 7.5751 - accuracy: 0.6673 - val_loss: 0.8900 - val_accuracy: 0.6748
# Epoch 61/100
# 154/154 [==============================] - 11s 74ms/step - loss: 1.1999 - accuracy: 0.7547 - val_loss: 0.6520 - val_accuracy: 0.7589
# Epoch 62/100
# 154/154 [==============================] - 12s 79ms/step - loss: 0.7765 - accuracy: 0.8146 - val_loss: 0.6150 - val_accuracy: 0.7866
# Epoch 63/100
# 154/154 [==============================] - 13s 87ms/step - loss: 0.4882 - accuracy: 0.8577 - val_loss: 0.4808 - val_accuracy: 0.8478
# Epoch 64/100
# 154/154 [==============================] - 12s 81ms/step - loss: 0.4978 - accuracy: 0.8652 - val_loss: 0.4381 - val_accuracy: 0.8601
# Epoch 65/100
# 154/154 [==============================] - 10s 65ms/step - loss: 0.4032 - accuracy: 0.8926 - val_loss: 0.4283 - val_accuracy: 0.8654
# Epoch 66/100
# 154/154 [==============================] - 11s 70ms/step - loss: 0.3469 - accuracy: 0.8996 - val_loss: 0.4406 - val_accuracy: 0.8576
# Epoch 67/100
# 154/154 [==============================] - 11s 72ms/step - loss: 0.3716 - accuracy: 0.9043 - val_loss: 0.4087 - val_accuracy: 0.8494
# Epoch 68/100
# 154/154 [==============================] - 10s 62ms/step - loss: 0.2759 - accuracy: 0.9180 - val_loss: 0.3750 - val_accuracy: 0.8956
# Epoch 69/100
# 154/154 [==============================] - 16s 103ms/step - loss: 0.3253 - accuracy: 0.9153 - val_loss: 0.3320 - val_accuracy: 0.9058
# Epoch 70/100
# 154/154 [==============================] - 14s 88ms/step - loss: 0.2299 - accuracy: 0.9314 - val_loss: 0.3519 - val_accuracy: 0.9086
# Epoch 71/100
# 154/154 [==============================] - 16s 107ms/step - loss: 0.2072 - accuracy: 0.9351 - val_loss: 0.3148 - val_accuracy: 0.9176
# Epoch 72/100
# 154/154 [==============================] - 13s 84ms/step - loss: 0.1958 - accuracy: 0.9399 - val_loss: 0.3855 - val_accuracy: 0.8878
# Epoch 73/100
# 154/154 [==============================] - 11s 75ms/step - loss: 0.2457 - accuracy: 0.9251 - val_loss: 0.4271 - val_accuracy: 0.8719
# Epoch 74/100
# 154/154 [==============================] - 15s 101ms/step - loss: 0.2146 - accuracy: 0.9314 - val_loss: 0.2974 - val_accuracy: 0.9233
# Epoch 75/100
# 154/154 [==============================] - 13s 85ms/step - loss: 0.1426 - accuracy: 0.9616 - val_loss: 0.3215 - val_accuracy: 0.9217
# Epoch 76/100
# 154/154 [==============================] - 11s 70ms/step - loss: 0.2093 - accuracy: 0.9331 - val_loss: 0.4903 - val_accuracy: 0.8678
# Epoch 77/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.1769 - accuracy: 0.9444 - val_loss: 0.2980 - val_accuracy: 0.9290
# Epoch 78/100
# 154/154 [==============================] - 13s 87ms/step - loss: 0.1312 - accuracy: 0.9599 - val_loss: 0.3044 - val_accuracy: 0.9310
# Epoch 79/100
# 154/154 [==============================] - 14s 92ms/step - loss: 0.1452 - accuracy: 0.9569 - val_loss: 0.2632 - val_accuracy: 0.9339
# Epoch 80/100
# 154/154 [==============================] - 14s 91ms/step - loss: 0.1511 - accuracy: 0.9524 - val_loss: 0.2486 - val_accuracy: 0.9486
# Epoch 81/100
# 154/154 [==============================] - 10s 67ms/step - loss: 0.1172 - accuracy: 0.9627 - val_loss: 0.3275 - val_accuracy: 0.9196
# Epoch 82/100
# 154/154 [==============================] - 13s 82ms/step - loss: 0.1300 - accuracy: 0.9611 - val_loss: 0.4290 - val_accuracy: 0.8947
# Epoch 83/100
# 154/154 [==============================] - 15s 97ms/step - loss: 0.2864 - accuracy: 0.9363 - val_loss: 0.4421 - val_accuracy: 0.8854
# Epoch 84/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.1186 - accuracy: 0.9642 - val_loss: 0.2982 - val_accuracy: 0.9290
# Epoch 85/100
# 154/154 [==============================] - 11s 70ms/step - loss: 0.1226 - accuracy: 0.9616 - val_loss: 0.2361 - val_accuracy: 0.9514
# Epoch 86/100
# 154/154 [==============================] - 11s 73ms/step - loss: 0.1003 - accuracy: 0.9648 - val_loss: 0.3246 - val_accuracy: 0.9188
# Epoch 87/100
# 154/154 [==============================] - 13s 84ms/step - loss: 0.0973 - accuracy: 0.9697 - val_loss: 0.2439 - val_accuracy: 0.9502
# Epoch 88/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.0974 - accuracy: 0.9713 - val_loss: 0.3219 - val_accuracy: 0.9306
# Epoch 89/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.1176 - accuracy: 0.9623 - val_loss: 0.2737 - val_accuracy: 0.9412
# Epoch 90/100
# 154/154 [==============================] - 12s 75ms/step - loss: 0.1005 - accuracy: 0.9682 - val_loss: 0.2621 - val_accuracy: 0.9433
# Epoch 91/100
# 154/154 [==============================] - 12s 80ms/step - loss: 0.0955 - accuracy: 0.9726 - val_loss: 0.2438 - val_accuracy: 0.9514
# Epoch 92/100
# 154/154 [==============================] - 13s 85ms/step - loss: 0.1415 - accuracy: 0.9546 - val_loss: 0.3546 - val_accuracy: 0.9119
# Epoch 93/100
# 154/154 [==============================] - 13s 85ms/step - loss: 0.0745 - accuracy: 0.9790 - val_loss: 0.2756 - val_accuracy: 0.9461
# Epoch 94/100
# 154/154 [==============================] - 14s 88ms/step - loss: 0.1557 - accuracy: 0.9513 - val_loss: 0.2686 - val_accuracy: 0.9388
# Epoch 95/100
# 154/154 [==============================] - 14s 88ms/step - loss: 0.0846 - accuracy: 0.9741 - val_loss: 0.2741 - val_accuracy: 0.9482
# Epoch 96/100
# 154/154 [==============================] - 14s 90ms/step - loss: 0.0910 - accuracy: 0.9708 - val_loss: 0.2852 - val_accuracy: 0.9449
# Epoch 97/100
# 154/154 [==============================] - 16s 103ms/step - loss: 0.1067 - accuracy: 0.9699 - val_loss: 0.2351 - val_accuracy: 0.9572
# Epoch 98/100
# 154/154 [==============================] - 15s 94ms/step - loss: 0.0989 - accuracy: 0.9724 - val_loss: 0.3020 - val_accuracy: 0.9376
# Epoch 99/100
# 154/154 [==============================] - 12s 78ms/step - loss: 0.0632 - accuracy: 0.9801 - val_loss: 0.2396 - val_accuracy: 0.9633
# Epoch 100/100
# 154/154 [==============================] - 11s 74ms/step - loss: 0.1213 - accuracy: 0.9602 - val_loss: 0.3546 - val_accuracy: 0.9323
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3546 - accuracy: 0.9323
# 77/77 [==============================] - 1s 8ms/step
# Confusion matrix
#  [[246   2   3   0   0   0   1   0   0   0]
#  [  1 238   0   1   1   0   0   0   0   0]
#  [ 25   3 249   3   1   2   0   2   0   0]
#  [  0   1   2 234   0   1   0   0   0   1]
#  [  3   0   0   1 255   6   0   5   1   1]
#  [  1   3   1   0   6 177   1   4   3   0]
#  [  0   0   0   1   8   2 265   2   1   0]
#  [  2   0   2   0   5   5   1 213   2   0]
#  [  0   0   0   0  10   2   7   1 233   7]
#  [  2   0   2   3   6   3   2   0   4 175]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92       252
#            1       0.96      0.99      0.98       241
#            2       0.96      0.87      0.92       285
#            3       0.96      0.98      0.97       239
#            4       0.87      0.94      0.90       272
#            5       0.89      0.90      0.90       196
#            6       0.96      0.95      0.95       279
#            7       0.94      0.93      0.93       230
#            8       0.95      0.90      0.92       260
#            9       0.95      0.89      0.92       197
#
#     accuracy                           0.93      2451
#    macro avg       0.93      0.93      0.93      2451
# weighted avg       0.93      0.93      0.93      2451

# %%
cf_matrix=confusion_matrix(y_test,y_pred)
print('Confusion matrix\n',cf_matrix)
print(classification_report(y_test,y_pred))
# Out:
# Confusion matrix
#  [[245   5   2   0   1   0   1   0   0   4]
#  [  2 237   0   1   1   0   0   2   1   0]
#  [ 27   0 236   2   1   0   0   1   0   1]
#  [  7   4   8 205   0   0   1   4   0   0]
#  [  0   0   0   0 261   1   1   2   1   4]
#  [  0   0   0   0  12 192   9  13   3   0]
#  [  0   0   0   0   8   0 257   1   0   0]
#  [  2   0   7   0   3   0   2 216   1   2]
#  [  1   0   0   0   3   0   0   2 250   3]
#  [  0   0   2   0   3   0   3   0   4 183]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90       258
#            1       0.96      0.97      0.97       244
#            2       0.93      0.88      0.90       268
#            3       0.99      0.90      0.94       229
#            4       0.89      0.97      0.93       270
#            5       0.99      0.84      0.91       229
#            6       0.94      0.97      0.95       266
#            7       0.90      0.93      0.91       233
#            8       0.96      0.97      0.96       259
#            9       0.93      0.94      0.93       195
#
#     accuracy                           0.93      2451
#    macro avg       0.93      0.93      0.93      2451
# weighted avg       0.93      0.93      0.93      2451

# %%
print('specificity:')
tot=0
for i in range (10):
    sum=0
    for j in range(10):
        sum=sum+cf_matrix[i,j]
    spec=cf_matrix[i,i]/sum
    tot+=spec
    print(i," ",spec)
print('specificity avg\n',tot/10)
# Out:
# specificity:
# 0   0.9496124031007752
# 1   0.9713114754098361
# 2   0.8805970149253731
# 3   0.8951965065502183
# 4   0.9666666666666667
# 5   0.8384279475982532
# 6   0.9661654135338346
# 7   0.927038626609442
# 8   0.9652509652509652
# 9   0.9384615384615385
# specificity avg
#  0.9298728558106903

# %%
acc_train = history.history["accuracy"]
acc_val = history.history["val_accuracy"]
epochs = range(1,99)
plt.plot(acc_train, 'g', label='Training accuracy')
plt.plot(acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss_train = history.history["loss"]
loss_val = history.history["val_loss"]
epochs = range(1,99)
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
