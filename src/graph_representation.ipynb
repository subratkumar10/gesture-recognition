# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1points = np.array([3,4,5,6,7,8,9,10])
y1points = np.array([0.97,0.98,0.96,0.965,0.958,0.991,0.98,0.997])
x2points = np.array([3,4,5,6,7,8,9,10])
y2points = np.array([0.95,0.88,0.89,0.892,0.78,0.768,0.82,0.846])
plt.plot(x1points, y1points,color='green',marker='o',label='Train Set')
plt.plot(x2points, y2points,color='blue',marker='o',label='Test Set')
plt.ylim(0.6,1)
plt.xlabel('Kernel size')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()

# %%
x1points = np.array([3,4,5,6,7,8,9,10])
y1points = np.array([0.97,0.98,0.982,0.99,0.954,0.96,0.91,0.92])
x2points = np.array([3,4,5,6,7,8,9,10])
y2points = np.array([0.95,0.94,0.948,0.949,0.94,0.92,0.86,0.828])
plt.plot(x1points, y1points,'g',label='Train Set',marker='o')
plt.plot(x2points, y2points,'b',label='Test Set',marker='o')
plt.ylim(0.6,1)
plt.xlabel('Pool size')
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.show()

# %%
x1points = np.array([0.0001,0.0002,0.0003,0.0004,0.0005,0.0006,0.0007,0.0008,0.0009,0.0010])
y1points = np.array([0.97,0.98,0.982,0.99,0.986,0.978,0.96,0.97,0.98,0.99])
x2points = np.array([0.0001,0.0002,0.0003,0.0004,0.0005,0.0006,0.0007,0.0008,0.0009,0.0010])
y2points = np.array([0.95,0.93,0.94,0.948,0.94,0.93,0.91,0.86,0.90,0.85])
plt.plot(x1points, y1points,'g',label='Train Set',marker='o')
plt.plot(x2points, y2points,'b',label='Test Set',marker='o')
plt.ylim(0.6,1)
plt.xlabel('Learing rate')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.xticks(rotation = 45)
plt.show()
