# %%
from dis import dis
# from tkinter.tix import AUTO
from requests import head
import torch
import config
import os
from glob import glob
from shutil import copyfile
import pandas as pd
import re
import numpy as np
from math import sqrt
import math
import tensorflow as tf
from keras import regularizers
from tensorflow.keras import Model, Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
from re import X
import numpy as np
import torch
import pandas as pd
from torch.nn.utils.rnn import pack_padded_sequence
from torch.utils.data import DataLoader
from CustomDataset import CustomRawDataset
from model_dispatcher import dispatch_model
# from model_dispatcher_cnn import dispatch_model
import config
from torch import nn
import os
from glob import glob
from torch.optim import Adam, SGD
from torch.optim.lr_scheduler import ReduceLROnPlateau
from datetime import date, timedelta, datetime
import time
import random
from torch.utils.tensorboard import SummaryWriter
from CustomDataset import custom_collate_fn
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation,TimeDistributed
from tensorflow.keras.layers import Bidirectional, GlobalMaxPool1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
raw_angle_files_1 = glob(os.path.join("D:\Research_Project\My_project_22\input\preprocessed", "*", "*.csv"))
# print(raw_angle_files_1)
all_filenames = [i for i in raw_angle_files_1]
df = pd.concat(map(pd.read_csv, all_filenames),ignore_index=True)
data=df
data.to_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\merged_modified.csv",index=False)
#df=pd.read_csv(r"D:\Research_Project\My_project_22\FEATURES_EXTRACTED\DISTANCES\both_hand_frontup_left_leg_frontup\aatish_both_hand_frontup_left_leg_frontup_trial1_interpolated.csv")
   
# data=df
# print(data.shape)
# target=data['54']
# data=data.drop(['54'],axis=1)
# # data.head()
# print(data.shape)
# AutoEncoder(data)
# data['12']=target
# print(data.shape)

# %%
data=pd.read_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\merged_modified.csv")
data.head()
# target=data['166']
# data=data.drop(['166'],axis=1)
target=data['target']
data=data.drop(['target'],axis=1)
# data.head()
# print(data.shape)
# AutoEncoder(data)
# data['12']=target
# print(data.shape)
print(data.shape)
print(target.shape)
# Out:
# (12260, 166)
# (12260,)

# %%
from sklearn.ensemble import RandomForestClassifier
# create the random forest with your hyperparameters.
model = RandomForestClassifier(n_estimators=342)

# fit the model to start training.

model.fit(data, target)

# get the importance of the resulting features.
importances = model.feature_importances_

# create a data frame for visualization.

final_df = pd.DataFrame({"Features": pd.DataFrame(data).columns, "Importances":importances})
final_df.set_index("Importances")

# sort in ascending order to better visualization.
final_df =final_df.sort_values('Importances')
plt.figure(figsize=(30,25))

# %%
# print(final_df)
plt.figure(figsize=(30,30))
plt.xlabel('Features',size=20)
plt.ylabel('Importances',size=20)
plt.bar(final_df['Features'],final_df['Importances'],label="Importance")
plt.xticks(final_df['Features'],rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x152eac43eb0>,
#   <matplotlib.axis.XTick at 0x152eac43e80>,
#   <matplotlib.axis.XTick at 0x152eac43b80>,
#   <matplotlib.axis.XTick at 0x152ead56e30>,
#   <matplotlib.axis.XTick at 0x152ead57580>,
#   <matplotlib.axis.XTick at 0x152ead57cd0>,
#   <matplotlib.axis.XTick at 0x152ead575b0>,
#   <matplotlib.axis.XTick at 0x152ead84340>,
#   <matplotlib.axis.XTick at 0x152ead84a90>,
#   <matplotlib.axis.XTick at 0x152ead851e0>,
#   <matplotlib.axis.XTick at 0x152ead85930>,
#   <matplotlib.axis.XTick at 0x152ead86080>,
#   <matplotlib.axis.XTick at 0x152ead575e0>,
#   <matplotlib.axis.XTick at 0x152ead85570>,
#   <matplotlib.axis.XTick at 0x152ead842b0>,
#   <matplotlib.axis.XTick at 0x152ead86e00>,
#   <matplotlib.axis.XTick at 0x152ead87550>,
#   <matplotlib.axis.XTick at 0x152ead87ca0>,
#   <matplotlib.axis.XTick at 0x152eada8430>,
#   <matplotlib.axis.XTick at 0x152ead87a60>,
#   <matplotlib.axis.XTick at 0x152ead867a0>,
#   <matplotlib.axis.XTick at 0x152eada83a0>,
#   <matplotlib.axis.XTick at 0x152eada8f70>,
#   <matplotlib.axis.XTick at 0x152eada96c0>,
#   <matplotlib.axis.XTick at 0x152eada9e10>,
#   <matplotlib.axis.XTick at 0x152eadaa560>,
#   <matplotlib.axis.XTick at 0x152ead87070>,
#   <matplotlib.axis.XTick at 0x152eada9930>,
#   <matplotlib.axis.XTick at 0x152eadaa950>,
#   <matplotlib.axis.XTick at 0x152eadab0a0>,
#   <matplotlib.axis.XTick at 0x152eadab7f0>,
#   <matplotlib.axis.XTick at 0x152eadc80a0>,
#   <matplotlib.axis.XTick at 0x152eadabcd0>,
#   <matplotlib.axis.XTick at 0x152eadaace0>,
#   <matplotlib.axis.XTick at 0x152eadc8670>,
#   <matplotlib.axis.XTick at 0x152eadc8be0>,
#   <matplotlib.axis.XTick at 0x152eadc9330>,
#   <matplotlib.axis.XTick at 0x152eadc9a80>,
#   <matplotlib.axis.XTick at 0x152eadca1d0>,
#   <matplotlib.axis.XTick at 0x152eada9030>,
#   <matplotlib.axis.XTick at 0x152eadc9d20>,
#   <matplotlib.axis.XTick at 0x152eadc8970>,
#   <matplotlib.axis.XTick at 0x152eadcae30>,
#   <matplotlib.axis.XTick at 0x152eadcb580>,
#   <matplotlib.axis.XTick at 0x152eadcbcd0>,
#   <matplotlib.axis.XTick at 0x152eade8460>,
#   <matplotlib.axis.XTick at 0x152eadcb940>,
#   <matplotlib.axis.XTick at 0x152eadc89a0>,
#   <matplotlib.axis.XTick at 0x152eadaba90>,
#   <matplotlib.axis.XTick at 0x152eade8430>,
#   <matplotlib.axis.XTick at 0x152eade8df0>,
#   <matplotlib.axis.XTick at 0x152eade9540>,
#   <matplotlib.axis.XTick at 0x152eade9c90>,
#   <matplotlib.axis.XTick at 0x152eadca470>,
#   <matplotlib.axis.XTick at 0x152eade9900>,
#   <matplotlib.axis.XTick at 0x152eadea080>,
#   <matplotlib.axis.XTick at 0x152eadea7d0>,
#   <matplotlib.axis.XTick at 0x152eadeaf20>,
#   <matplotlib.axis.XTick at 0x152eadeb670>,
#   <matplotlib.axis.XTick at 0x152eadcb1f0>,
#   <matplotlib.axis.XTick at 0x152eadeb5e0>,
#   <matplotlib.axis.XTick at 0x152eadea2f0>,
#   <matplotlib.axis.XTick at 0x152eae04280>,
#   <matplotlib.axis.XTick at 0x152eae049d0>,
#   <matplotlib.axis.XTick at 0x152eae05120>,
#   <matplotlib.axis.XTick at 0x152eae05870>,
#   <matplotlib.axis.XTick at 0x152eadeaa70>,
#   <matplotlib.axis.XTick at 0x152eae058d0>,
#   <matplotlib.axis.XTick at 0x152eae04550>,
#   <matplotlib.axis.XTick at 0x152eae064d0>,
#   <matplotlib.axis.XTick at 0x152eae06c20>,
#   <matplotlib.axis.XTick at 0x152eae07370>,
#   <matplotlib.axis.XTick at 0x152eae07ac0>,
#   <matplotlib.axis.XTick at 0x152eae07a90>,
#   <matplotlib.axis.XTick at 0x152eae06980>,
#   <matplotlib.axis.XTick at 0x152eae1c040>,
#   <matplotlib.axis.XTick at 0x152eae1c640>,
#   <matplotlib.axis.XTick at 0x152eae1cd90>,
#   <matplotlib.axis.XTick at 0x152eae1d4e0>,
#   <matplotlib.axis.XTick at 0x152eae1dc30>,
#   <matplotlib.axis.XTick at 0x152eae068c0>,
#   <matplotlib.axis.XTick at 0x152eae1d270>,
#   <matplotlib.axis.XTick at 0x152eae1e020>,
#   <matplotlib.axis.XTick at 0x152eae1e770>,
#   <matplotlib.axis.XTick at 0x152eae1eec0>,
#   <matplotlib.axis.XTick at 0x152eae1f610>,
#   <matplotlib.axis.XTick at 0x152eae07130>,
#   <matplotlib.axis.XTick at 0x152eae1f250>,
#   <matplotlib.axis.XTick at 0x152eae1c190>,
#   <matplotlib.axis.XTick at 0x152eae44220>,
#   <matplotlib.axis.XTick at 0x152eae44970>,
#   <matplotlib.axis.XTick at 0x152eae450c0>,
#   <matplotlib.axis.XTick at 0x152eae45810>,
#   <matplotlib.axis.XTick at 0x152eae1e080>,
#   <matplotlib.axis.XTick at 0x152eae45840>,
#   <matplotlib.axis.XTick at 0x152eae444c0>,
#   <matplotlib.axis.XTick at 0x152eae46470>,
#   <matplotlib.axis.XTick at 0x152eae46bc0>,
#   <matplotlib.axis.XTick at 0x152eae47310>,
#   <matplotlib.axis.XTick at 0x152eae47a60>,
#   <matplotlib.axis.XTick at 0x152eae47a30>,
#   <matplotlib.axis.XTick at 0x152eae46920>,
#   <matplotlib.axis.XTick at 0x152eae45780>,
#   <matplotlib.axis.XTick at 0x152eae585e0>,
#   <matplotlib.axis.XTick at 0x152eae58d30>,
#   <matplotlib.axis.XTick at 0x152eae59480>,
#   <matplotlib.axis.XTick at 0x152eae59bd0>,
#   <matplotlib.axis.XTick at 0x152eae46860>,
#   <matplotlib.axis.XTick at 0x152eae59210>,
#   <matplotlib.axis.XTick at 0x152eae59fc0>,
#   <matplotlib.axis.XTick at 0x152eae5a710>,
#   <matplotlib.axis.XTick at 0x152eae5ae60>,
#   <matplotlib.axis.XTick at 0x152eae5b5b0>,
#   <matplotlib.axis.XTick at 0x152eae470d0>,
#   <matplotlib.axis.XTick at 0x152eae5b1f0>,
#   <matplotlib.axis.XTick at 0x152eae58130>,
#   <matplotlib.axis.XTick at 0x152eae741c0>,
#   <matplotlib.axis.XTick at 0x152eae74910>,
#   <matplotlib.axis.XTick at 0x152eae75060>,
#   <matplotlib.axis.XTick at 0x152eae757b0>,
#   <matplotlib.axis.XTick at 0x152eae5a020>,
#   <matplotlib.axis.XTick at 0x152eae757e0>,
#   <matplotlib.axis.XTick at 0x152eae74460>,
#   <matplotlib.axis.XTick at 0x152eae76410>,
#   <matplotlib.axis.XTick at 0x152eae76b60>,
#   <matplotlib.axis.XTick at 0x152eae772b0>,
#   <matplotlib.axis.XTick at 0x152eae77a00>,
#   <matplotlib.axis.XTick at 0x152eae58fa0>,
#   <matplotlib.axis.XTick at 0x152eae07f70>,
#   <matplotlib.axis.XTick at 0x152eae77970>,
#   <matplotlib.axis.XTick at 0x152eae76680>,
#   <matplotlib.axis.XTick at 0x152eae75c60>,
#   <matplotlib.axis.XTick at 0x152eae984f0>,
#   <matplotlib.axis.XTick at 0x152eae98c40>,
#   <matplotlib.axis.XTick at 0x152eae766b0>,
#   <matplotlib.axis.XTick at 0x152eae47df0>,
#   <matplotlib.axis.XTick at 0x152eae99030>,
#   <matplotlib.axis.XTick at 0x152eae99780>,
#   <matplotlib.axis.XTick at 0x152eae99ed0>,
#   <matplotlib.axis.XTick at 0x152eae9a620>,
#   <matplotlib.axis.XTick at 0x152eae59810>,
#   <matplotlib.axis.XTick at 0x152eae9a890>,
#   <matplotlib.axis.XTick at 0x152eae994e0>,
#   <matplotlib.axis.XTick at 0x152eae9b1f0>,
#   <matplotlib.axis.XTick at 0x152eae9b940>,
#   <matplotlib.axis.XTick at 0x152f0ab40d0>,
#   <matplotlib.axis.XTick at 0x152f0ab4820>,
#   <matplotlib.axis.XTick at 0x152eae9b9a0>,
#   <matplotlib.axis.XTick at 0x152eae99c90>,
#   <matplotlib.axis.XTick at 0x152f0ab4370>,
#   <matplotlib.axis.XTick at 0x152f0ab5480>,
#   <matplotlib.axis.XTick at 0x152f0ab5bd0>,
#   <matplotlib.axis.XTick at 0x152f0ab6320>,
#   <matplotlib.axis.XTick at 0x152f0ab6a70>,
#   <matplotlib.axis.XTick at 0x152eae988e0>,
#   <matplotlib.axis.XTick at 0x152f0ab5f60>,
#   <matplotlib.axis.XTick at 0x152f0ab4490>,
#   <matplotlib.axis.XTick at 0x152f0ab75b0>,
#   <matplotlib.axis.XTick at 0x152f0ab7d00>,
#   <matplotlib.axis.XTick at 0x152f0acc490>,
#   <matplotlib.axis.XTick at 0x152f0accbe0>,
#   <matplotlib.axis.XTick at 0x152f0ab76a0>,
#   <matplotlib.axis.XTick at 0x152eae9bc10>,
#   <matplotlib.axis.XTick at 0x152f0accfd0>,
#   <matplotlib.axis.XTick at 0x152f0acd720>,
#   <matplotlib.axis.XTick at 0x152f0acde70>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
x=list(final_df['Features'])
y=list(final_df['Importances'])
y1=[]
x1=[]
sorted_id=[]
for i in range(-70,0):
    x[i]=str(x[i])
    sorted_id.append(x[i])
    y1.append(y[i])
x1=sorted_id

data=data[sorted_id] 
data.head()
data.columns
# Out:
# Index(['dist_5_13', 'dist_3_1', 'dist_14_1', 'dist_15_18', 'dist_21_24',
#        'dist_17_18', '2', 'dist_14_13', 'centroid_3_23_19_c', '11',
#        'dist_15_19', 'dist_15_17', 'dist_14_17', 'centroid_19_23_20_c',
#        'dist_17_13', 'centroid_5_21_12_c', 'dist_16_17', 'dist_16_1',
#        'centroid_20_0_21_c', 'dist_4_9', 'dist_0_1', 'centroid_15_21_20_c',
#        '3', 'dist_14_19', 'centroid_19_23_20_a', '6', 'dist_2_1',
#        'centroid_20_0_23_c', 'centroid_15_1_10_c', 'dist_20_1',
#        'centroid_9_23_16_c', 'centroid_3_23_16_c', 'centroid_3_23_19_a',
#        'centroid_15_1_10_a', 'dist_14_18', '7', 'dist_21_23', '14',
#        'centroid_5_21_12_a', 'dist_22_24', 'centroid_20_0_21_a',
#        'centroid_0_15_19_c', 'centroid_20_0_23_a', 'centroid_0_13_17_a', '1',
#        'centroid_15_12_19_c', 'dist_8_1', 'centroid_19_16_15_c',
#        'centroid_9_23_16_a', 'dist_23_21', 'centroid_3_23_16_a',
#        'centroid_20_5_1_c', 'centroid_0_13_17_c', 'centroid_20_9_1_c',
#        'dist_4_1', 'dist_22_23', 'dist_7_11', '5', 'centroid_20_5_1_a',
#        'centroid_20_9_1_a', 'centroid_0_14_18_c', 'centroid_0_14_18_a',
#        'centroid_15_12_19_a', '12', '10', 'dist_6_11', 'centroid_19_16_15_a',
#        'centroid_0_15_19_a', '13', '9'],
#       dtype='object')

# %%
# print(final_df)
plt.figure(figsize=(30,30))
plt.xlabel('Features',size=20)
plt.ylabel('Importances',size=20)
plt.bar(x1,y1,label="Importance")
plt.xticks(x1,rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x152f0b81420>,
#   <matplotlib.axis.XTick at 0x152f0b81660>,
#   <matplotlib.axis.XTick at 0x152f0b44d90>,
#   <matplotlib.axis.XTick at 0x152f15a2e90>,
#   <matplotlib.axis.XTick at 0x152f15a35e0>,
#   <matplotlib.axis.XTick at 0x152f15a3d30>,
#   <matplotlib.axis.XTick at 0x152f15d04c0>,
#   <matplotlib.axis.XTick at 0x152f15a3ca0>,
#   <matplotlib.axis.XTick at 0x152f1549ab0>,
#   <matplotlib.axis.XTick at 0x152f15d0e50>,
#   <matplotlib.axis.XTick at 0x152f15d15a0>,
#   <matplotlib.axis.XTick at 0x152f15d1cf0>,
#   <matplotlib.axis.XTick at 0x152f15d2440>,
#   <matplotlib.axis.XTick at 0x152f15d2b90>,
#   <matplotlib.axis.XTick at 0x152f15a39d0>,
#   <matplotlib.axis.XTick at 0x152f15d1f90>,
#   <matplotlib.axis.XTick at 0x152f15d04f0>,
#   <matplotlib.axis.XTick at 0x152f15d37f0>,
#   <matplotlib.axis.XTick at 0x152f15f00a0>,
#   <matplotlib.axis.XTick at 0x152f15f06d0>,
#   <matplotlib.axis.XTick at 0x152f15f0e20>,
#   <matplotlib.axis.XTick at 0x152f15d3b80>,
#   <matplotlib.axis.XTick at 0x152f15d20b0>,
#   <matplotlib.axis.XTick at 0x152f15f1300>,
#   <matplotlib.axis.XTick at 0x152f15f13c0>,
#   <matplotlib.axis.XTick at 0x152f15f1b10>,
#   <matplotlib.axis.XTick at 0x152f15f2260>,
#   <matplotlib.axis.XTick at 0x152f15f29b0>,
#   <matplotlib.axis.XTick at 0x152f15d0730>,
#   <matplotlib.axis.XTick at 0x152f15f1ea0>,
#   <matplotlib.axis.XTick at 0x152f15f2da0>,
#   <matplotlib.axis.XTick at 0x152f15f34f0>,
#   <matplotlib.axis.XTick at 0x152f15f3c40>,
#   <matplotlib.axis.XTick at 0x152f16083d0>,
#   <matplotlib.axis.XTick at 0x152f15f3d00>,
#   <matplotlib.axis.XTick at 0x152f15f0df0>,
#   <matplotlib.axis.XTick at 0x152f1608ac0>,
#   <matplotlib.axis.XTick at 0x152f1608fa0>,
#   <matplotlib.axis.XTick at 0x152f16096f0>,
#   <matplotlib.axis.XTick at 0x152f1609e40>,
#   <matplotlib.axis.XTick at 0x152f160a590>,
#   <matplotlib.axis.XTick at 0x152f15f2d70>,
#   <matplotlib.axis.XTick at 0x152f1609f30>,
#   <matplotlib.axis.XTick at 0x152f1608190>,
#   <matplotlib.axis.XTick at 0x152f160b1f0>,
#   <matplotlib.axis.XTick at 0x152f160b940>,
#   <matplotlib.axis.XTick at 0x152e76340d0>,
#   <matplotlib.axis.XTick at 0x152e7634820>,
#   <matplotlib.axis.XTick at 0x152f160b970>,
#   <matplotlib.axis.XTick at 0x152f16097b0>,
#   <matplotlib.axis.XTick at 0x152e76340a0>,
#   <matplotlib.axis.XTick at 0x152e7635360>,
#   <matplotlib.axis.XTick at 0x152e7635ab0>,
#   <matplotlib.axis.XTick at 0x152e7636200>,
#   <matplotlib.axis.XTick at 0x152e7636950>,
#   <matplotlib.axis.XTick at 0x152e7636ce0>,
#   <matplotlib.axis.XTick at 0x152e7635b70>,
#   <matplotlib.axis.XTick at 0x152e7636d40>,
#   <matplotlib.axis.XTick at 0x152e7637490>,
#   <matplotlib.axis.XTick at 0x152e7637be0>,
#   <matplotlib.axis.XTick at 0x152e7658370>,
#   <matplotlib.axis.XTick at 0x152e7637eb0>,
#   <matplotlib.axis.XTick at 0x152e7636e00>,
#   <matplotlib.axis.XTick at 0x152e76589a0>,
#   <matplotlib.axis.XTick at 0x152e7658f40>,
#   <matplotlib.axis.XTick at 0x152e7659690>,
#   <matplotlib.axis.XTick at 0x152e7659de0>,
#   <matplotlib.axis.XTick at 0x152e765a530>,
#   <matplotlib.axis.XTick at 0x152e7635000>,
#   <matplotlib.axis.XTick at 0x152e7659ea0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data.shape
# Out:
# (12260, 70)

# %%
data.head()
# Out:
#    dist_5_13  dist_3_1  dist_14_1  dist_15_18  dist_21_24  dist_17_18  \
# 0   0.668269  0.475169   1.092358    0.159106    0.402950    0.388444
# 1   0.667384  0.470942   1.089962    0.156329    0.455762    0.374783
# 2   0.667259  0.469381   1.089337    0.156213    0.470410    0.370093
# 3   0.667317  0.469090   1.089422    0.156523    0.468654    0.369741
# 4   0.666881  0.469092   1.089527    0.156613    0.470034    0.369785
#
#           2  dist_14_13  centroid_3_23_19_c        11  ...  \
# 0  0.184621    0.376884            2.194733  0.081955  ...
# 1  0.161124    0.364950            2.207200  0.106628  ...
# 2  0.153572    0.360622            2.212433  0.115748  ...
# 3  0.153380    0.360186            2.212833  0.116238  ...
# 4  0.153946    0.360718            2.211367  0.115037  ...
#
#    centroid_0_14_18_c  centroid_0_14_18_a  centroid_15_12_19_a        12  \
# 0            2.316167            0.375580             0.346157  0.113375
# 1            2.317200            0.379317             0.350710  0.088090
# 2            2.317700            0.380610             0.352113  0.079567
# 3            2.317867            0.380717             0.352107  0.078291
# 4            2.317967            0.380730             0.352097  0.077394
#
#          10  dist_6_11  centroid_19_16_15_a  centroid_0_15_19_a        13  \
# 0 -0.027582   0.414414             0.397397            0.373833  0.031990
# 1 -0.009114   0.436329             0.401893            0.378393  0.029938
# 2 -0.002401   0.442395             0.403303            0.379813  0.029953
# 3 -0.001148   0.441379             0.403313            0.379817  0.030147
# 4 -0.000888   0.441859             0.403287            0.379800  0.030157
#
#           9
# 0  0.162107
# 1  0.157114
# 2  0.156264
# 3  0.155941
# 4  0.155132
#
# [5 rows x 70 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr=data.corr()
plt.figure(figsize=(30,25))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
def cal_snr(x):
    mean=np.mean(x)
    standard_deviation=np.std(x)
    snr=abs(mean/standard_deviation)
    return snr

# %%
threshold=0.8

column_name=[i for i in data.columns]
result=df[df>threshold]
result
vis_list=[]
reduced_attr=[]
for i in range(70):
    df=abs(corr[column_name[i]])
    result=df[df>threshold]
    max_index=""
    max_value=-1
    for j in result.index:
        snr_val=cal_snr(data[j].values)
        if((max_value<snr_val) and (j not in vis_list)):
            max_value=snr_val
            max_index=j
    for xp in result.index:
        vis_list.append(xp)
    if(max_value==-1):
        continue
    reduced_attr.append(max_index)


    

    # vis_list.append(list(result))
    # print('correlation of feature ',column_name[i],'\n',result,'\n')
# data=data.drop(['2','4','5','8','11'],axis=1)
# data.head()

# %%
data=data[reduced_attr]
reduced_attr
# Out:
# ['dist_14_18', '2', '11', '3', '7', '14', '1', '5', '12', '10', '13', '9']

# %%
data.head()
# Out:
#    dist_14_18         2        11         3         7        14         1  \
# 0    0.126636  0.184621  0.081955 -1.125618  1.246003  0.131282  1.650141
# 1    0.125783  0.161124  0.106628 -1.077973  1.296214  0.127583  1.632925
# 2    0.126060  0.153572  0.115748 -1.061660  1.306293  0.126045  1.627664
# 3    0.126405  0.153380  0.116238 -1.055622  1.302433  0.125562  1.626473
# 4    0.126424  0.153946  0.115037 -1.047045  1.296863  0.125631  1.624955
#
#           5        12        10        13         9
# 0  1.597459  0.113375 -0.027582  0.031990  0.162107
# 1  1.614270  0.088090 -0.009114  0.029938  0.157114
# 2  1.619788  0.079567 -0.002401  0.029953  0.156264
# 3  1.619716  0.078291 -0.001148  0.030147  0.155941
# 4  1.619620  0.077394 -0.000888  0.030157  0.155132

# %%
data['target']=target
data.head()
# Out:
#    dist_14_18         2        11         3         7        14         1  \
# 0    0.126636  0.184621  0.081955 -1.125618  1.246003  0.131282  1.650141
# 1    0.125783  0.161124  0.106628 -1.077973  1.296214  0.127583  1.632925
# 2    0.126060  0.153572  0.115748 -1.061660  1.306293  0.126045  1.627664
# 3    0.126405  0.153380  0.116238 -1.055622  1.302433  0.125562  1.626473
# 4    0.126424  0.153946  0.115037 -1.047045  1.296863  0.125631  1.624955
#
#           5        12        10        13         9  target
# 0  1.597459  0.113375 -0.027582  0.031990  0.162107       0
# 1  1.614270  0.088090 -0.009114  0.029938  0.157114       0
# 2  1.619788  0.079567 -0.002401  0.029953  0.156264       0
# 3  1.619716  0.078291 -0.001148  0.030147  0.155941       0
# 4  1.619620  0.077394 -0.000888  0.030157  0.155132       0

# %%
data.shape
# Out:
# (12260, 13)

# %%
data.to_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\random_tree_classifier_corr_snr_modified.csv",index=False)

# %%
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :12], sequences[end_ix-1, 12:]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
data=pd.read_csv(r"D:\Research_Project\My_project_22\input\final_preprocessed_merged\random_tree_classifier_corr_snr_modified.csv")
data=pd.get_dummies(data,columns=['target'])
data=data.to_numpy()
x,y=split_sequences(data,6)
# x=x[None:]
# print(x.shape)
# print(y.shape)
# data=data.to_numpy()
print(data.shape)

# y=data.iloc[:,26:]
# x=data.iloc[:,:26]
# # x=data[-1:26]
# print(x.shape)
# print(y.shape)
# x=x.to_numpy()
# y=y.to_numpy()
x_train,x_test,y_train,y_test= train_test_split(x, y, test_size = 0.2)
print(x_train.shape)
print(y_train.shape)
print(type(y_train))



model = Sequential()
model.add(layers.Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(6,12)))
model.add(layers.Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(Dense(100, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dense(10, activation='softmax'))

model.summary()


# model.summary()
# # log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# # tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# # print(x.shape)
history = model.fit(x_train, y_train,batch_size=config.BATCH_SIZE,epochs=100,validation_data=(x_test,y_test),verbose=1)
results = model.evaluate(x_test, y_test)
y_pred=model.predict(x_test)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# print(y_pred)
# Out:
# (12260, 22)
# (9804, 6, 12)
# (9804, 10)
# <class 'numpy.ndarray'>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             2368
#
#  conv1d_1 (Conv1D)           (None, 2, 64)             12352
#
#  dropout (Dropout)           (None, 2, 64)             0
#
#  max_pooling1d (MaxPooling1D  (None, 1, 64)            0
#  )
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 100)               6500
#
#  batch_normalization (BatchN  (None, 100)              400
#  ormalization)
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 22,630
# Trainable params: 22,430
# Non-trainable params: 200
# _________________________________________________________________
# Epoch 1/100
# 154/154 [==============================] - 4s 9ms/step - loss: 2.1337 - accuracy: 0.2418 - val_loss: 2.0879 - val_accuracy: 0.3623
# Epoch 2/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.7074 - accuracy: 0.3788 - val_loss: 1.8973 - val_accuracy: 0.4419
# Epoch 3/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.5559 - accuracy: 0.4210 - val_loss: 1.7357 - val_accuracy: 0.4574
# Epoch 4/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.4602 - accuracy: 0.4622 - val_loss: 1.6524 - val_accuracy: 0.4378
# Epoch 5/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.3842 - accuracy: 0.4897 - val_loss: 1.5745 - val_accuracy: 0.4994
# Epoch 6/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.3231 - accuracy: 0.5072 - val_loss: 1.4437 - val_accuracy: 0.5218
# Epoch 7/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.2676 - accuracy: 0.5331 - val_loss: 1.3813 - val_accuracy: 0.5430
# Epoch 8/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.1944 - accuracy: 0.5555 - val_loss: 1.3154 - val_accuracy: 0.5569
# Epoch 9/100
# 154/154 [==============================] - 1s 6ms/step - loss: 1.1452 - accuracy: 0.5752 - val_loss: 1.2348 - val_accuracy: 0.5879
# Epoch 10/100
# 154/154 [==============================] - 1s 6ms/step - loss: 1.0902 - accuracy: 0.5992 - val_loss: 1.1919 - val_accuracy: 0.6034
# Epoch 11/100
# 154/154 [==============================] - 1s 6ms/step - loss: 1.0603 - accuracy: 0.6129 - val_loss: 1.1916 - val_accuracy: 0.6030
# Epoch 12/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.0331 - accuracy: 0.6146 - val_loss: 1.1069 - val_accuracy: 0.6112
# Epoch 13/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.9711 - accuracy: 0.6411 - val_loss: 1.1096 - val_accuracy: 0.6446
# Epoch 14/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.9293 - accuracy: 0.6571 - val_loss: 1.0381 - val_accuracy: 0.6679
# Epoch 15/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.8801 - accuracy: 0.6739 - val_loss: 1.0059 - val_accuracy: 0.6879
# Epoch 16/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.8772 - accuracy: 0.6774 - val_loss: 0.9921 - val_accuracy: 0.6744
# Epoch 17/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.8405 - accuracy: 0.6852 - val_loss: 0.8864 - val_accuracy: 0.7258
# Epoch 18/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.8238 - accuracy: 0.7014 - val_loss: 0.8539 - val_accuracy: 0.7205
# Epoch 19/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.7734 - accuracy: 0.7128 - val_loss: 0.8636 - val_accuracy: 0.7226
# Epoch 20/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.7341 - accuracy: 0.7289 - val_loss: 0.7494 - val_accuracy: 0.7678
# Epoch 21/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.7126 - accuracy: 0.7380 - val_loss: 0.7296 - val_accuracy: 0.7760
# Epoch 22/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.7198 - accuracy: 0.7351 - val_loss: 0.7812 - val_accuracy: 0.7421
# Epoch 23/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6914 - accuracy: 0.7476 - val_loss: 0.7509 - val_accuracy: 0.7699
# Epoch 24/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6689 - accuracy: 0.7559 - val_loss: 0.8050 - val_accuracy: 0.7336
# Epoch 25/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6407 - accuracy: 0.7718 - val_loss: 0.6442 - val_accuracy: 0.8029
# Epoch 26/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6013 - accuracy: 0.7855 - val_loss: 0.6297 - val_accuracy: 0.8029
# Epoch 27/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6048 - accuracy: 0.7783 - val_loss: 0.6846 - val_accuracy: 0.7768
# Epoch 28/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5867 - accuracy: 0.7894 - val_loss: 0.5864 - val_accuracy: 0.8184
# Epoch 29/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5908 - accuracy: 0.7893 - val_loss: 0.6280 - val_accuracy: 0.8213
# Epoch 30/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5651 - accuracy: 0.7952 - val_loss: 0.5986 - val_accuracy: 0.8095
# Epoch 31/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5515 - accuracy: 0.8003 - val_loss: 0.5658 - val_accuracy: 0.8348
# Epoch 32/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5425 - accuracy: 0.8073 - val_loss: 0.5659 - val_accuracy: 0.8290
# Epoch 33/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5274 - accuracy: 0.8100 - val_loss: 0.5913 - val_accuracy: 0.8062
# Epoch 34/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5040 - accuracy: 0.8209 - val_loss: 0.5552 - val_accuracy: 0.8364
# Epoch 35/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4921 - accuracy: 0.8224 - val_loss: 0.5216 - val_accuracy: 0.8519
# Epoch 36/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4855 - accuracy: 0.8267 - val_loss: 0.5206 - val_accuracy: 0.8433
# Epoch 37/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4666 - accuracy: 0.8327 - val_loss: 0.5387 - val_accuracy: 0.8184
# Epoch 38/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4730 - accuracy: 0.8318 - val_loss: 0.4716 - val_accuracy: 0.8666
# Epoch 39/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4508 - accuracy: 0.8400 - val_loss: 0.4419 - val_accuracy: 0.8874
# Epoch 40/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4555 - accuracy: 0.8385 - val_loss: 0.4930 - val_accuracy: 0.8494
# Epoch 41/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4328 - accuracy: 0.8479 - val_loss: 0.4655 - val_accuracy: 0.8645
# Epoch 42/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4378 - accuracy: 0.8460 - val_loss: 0.4927 - val_accuracy: 0.8613
# Epoch 43/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4439 - accuracy: 0.8446 - val_loss: 0.4861 - val_accuracy: 0.8641
# Epoch 44/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4357 - accuracy: 0.8425 - val_loss: 0.5234 - val_accuracy: 0.8429
# Epoch 45/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4707 - accuracy: 0.8374 - val_loss: 0.4497 - val_accuracy: 0.8650
# Epoch 46/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4121 - accuracy: 0.8563 - val_loss: 0.4625 - val_accuracy: 0.8625
# Epoch 47/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4278 - accuracy: 0.8486 - val_loss: 0.4051 - val_accuracy: 0.8809
# Epoch 48/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.4034 - accuracy: 0.8616 - val_loss: 0.4049 - val_accuracy: 0.8764
# Epoch 49/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4057 - accuracy: 0.8585 - val_loss: 0.5435 - val_accuracy: 0.8274
# Epoch 50/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3949 - accuracy: 0.8654 - val_loss: 0.3809 - val_accuracy: 0.9119
# Epoch 51/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3730 - accuracy: 0.8685 - val_loss: 0.4177 - val_accuracy: 0.8841
# Epoch 52/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4009 - accuracy: 0.8584 - val_loss: 0.4321 - val_accuracy: 0.8886
# Epoch 53/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3660 - accuracy: 0.8715 - val_loss: 0.4252 - val_accuracy: 0.8772
# Epoch 54/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3558 - accuracy: 0.8792 - val_loss: 0.4417 - val_accuracy: 0.8617
# Epoch 55/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3825 - accuracy: 0.8668 - val_loss: 0.4993 - val_accuracy: 0.8323
# Epoch 56/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3726 - accuracy: 0.8701 - val_loss: 0.3872 - val_accuracy: 0.8956
# Epoch 57/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3590 - accuracy: 0.8768 - val_loss: 0.3849 - val_accuracy: 0.8833
# Epoch 58/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3552 - accuracy: 0.8787 - val_loss: 0.3623 - val_accuracy: 0.9074
# Epoch 59/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3508 - accuracy: 0.8776 - val_loss: 0.4382 - val_accuracy: 0.8654
# Epoch 60/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3389 - accuracy: 0.8819 - val_loss: 0.4103 - val_accuracy: 0.8841
# Epoch 61/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3506 - accuracy: 0.8788 - val_loss: 0.3618 - val_accuracy: 0.9053
# Epoch 62/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3529 - accuracy: 0.8799 - val_loss: 0.3601 - val_accuracy: 0.9041
# Epoch 63/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3487 - accuracy: 0.8793 - val_loss: 0.3723 - val_accuracy: 0.8931
# Epoch 64/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3509 - accuracy: 0.8796 - val_loss: 0.3666 - val_accuracy: 0.8947
# Epoch 65/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3401 - accuracy: 0.8829 - val_loss: 0.3971 - val_accuracy: 0.8821
# Epoch 66/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3429 - accuracy: 0.8797 - val_loss: 0.3747 - val_accuracy: 0.8931
# Epoch 67/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3480 - accuracy: 0.8795 - val_loss: 0.3653 - val_accuracy: 0.8915
# Epoch 68/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3296 - accuracy: 0.8875 - val_loss: 0.3359 - val_accuracy: 0.9058
# Epoch 69/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3186 - accuracy: 0.8887 - val_loss: 0.3075 - val_accuracy: 0.9188
# Epoch 70/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3312 - accuracy: 0.8870 - val_loss: 0.3231 - val_accuracy: 0.9155
# Epoch 71/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3149 - accuracy: 0.8929 - val_loss: 0.2845 - val_accuracy: 0.9184
# Epoch 72/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3081 - accuracy: 0.8923 - val_loss: 0.3529 - val_accuracy: 0.8976
# Epoch 73/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3296 - accuracy: 0.8868 - val_loss: 0.3472 - val_accuracy: 0.8915
# Epoch 74/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3138 - accuracy: 0.8944 - val_loss: 0.2653 - val_accuracy: 0.9290
# Epoch 75/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3064 - accuracy: 0.8940 - val_loss: 0.2874 - val_accuracy: 0.9184
# Epoch 76/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3201 - accuracy: 0.8925 - val_loss: 0.2874 - val_accuracy: 0.9094
# Epoch 77/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3238 - accuracy: 0.8920 - val_loss: 0.3242 - val_accuracy: 0.8984
# Epoch 78/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.3233 - accuracy: 0.8894 - val_loss: 0.3051 - val_accuracy: 0.9208
# Epoch 79/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3140 - accuracy: 0.8913 - val_loss: 0.3099 - val_accuracy: 0.9115
# Epoch 80/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3038 - accuracy: 0.8983 - val_loss: 0.2876 - val_accuracy: 0.9192
# Epoch 81/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2879 - accuracy: 0.9000 - val_loss: 0.3659 - val_accuracy: 0.8854
# Epoch 82/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3101 - accuracy: 0.8956 - val_loss: 0.2684 - val_accuracy: 0.9229
# Epoch 83/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2937 - accuracy: 0.8989 - val_loss: 0.3338 - val_accuracy: 0.8972
# Epoch 84/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2928 - accuracy: 0.8979 - val_loss: 0.3522 - val_accuracy: 0.8845
# Epoch 85/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2956 - accuracy: 0.9013 - val_loss: 0.3201 - val_accuracy: 0.8988
# Epoch 86/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2933 - accuracy: 0.8978 - val_loss: 0.2584 - val_accuracy: 0.9192
# Epoch 87/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2794 - accuracy: 0.9054 - val_loss: 0.2727 - val_accuracy: 0.9217
# Epoch 88/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2920 - accuracy: 0.8978 - val_loss: 0.2992 - val_accuracy: 0.9021
# Epoch 89/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3097 - accuracy: 0.8973 - val_loss: 0.2793 - val_accuracy: 0.9172
# Epoch 90/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2814 - accuracy: 0.9020 - val_loss: 0.2782 - val_accuracy: 0.9221
# Epoch 91/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2844 - accuracy: 0.9012 - val_loss: 0.3226 - val_accuracy: 0.9013
# Epoch 92/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2628 - accuracy: 0.9106 - val_loss: 0.2529 - val_accuracy: 0.9282
# Epoch 93/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2735 - accuracy: 0.9087 - val_loss: 0.2585 - val_accuracy: 0.9294
# Epoch 94/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2723 - accuracy: 0.9075 - val_loss: 0.2409 - val_accuracy: 0.9257
# Epoch 95/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2636 - accuracy: 0.9094 - val_loss: 0.2617 - val_accuracy: 0.9188
# Epoch 96/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2728 - accuracy: 0.9077 - val_loss: 0.2794 - val_accuracy: 0.9135
# Epoch 97/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2652 - accuracy: 0.9097 - val_loss: 0.2654 - val_accuracy: 0.9249
# Epoch 98/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.2942 - accuracy: 0.8974 - val_loss: 0.3142 - val_accuracy: 0.9017
# Epoch 99/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2626 - accuracy: 0.9099 - val_loss: 0.3786 - val_accuracy: 0.8772
# Epoch 100/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.2753 - accuracy: 0.9064 - val_loss: 0.2647 - val_accuracy: 0.9233
# 77/77 [==============================] - 0s 3ms/step - loss: 0.2647 - accuracy: 0.9233
# 77/77 [==============================] - 0s 2ms/step

# %%
cf_matrix=metrics.confusion_matrix(y_test,y_pred)
print('Confusion matrix\n',cf_matrix)
print(metrics.classification_report(y_test,y_pred))
# Out:
# Confusion matrix
#  [[294   1   0   0   5   0   0   0   0   0]
#  [ 12 218   4   1   0   0   0   0   2   0]
#  [  0   1 238  12   0   0   0   1   0   0]
#  [  1   4   1 211   1   0   3   0   1   0]
#  [  1   0   0   0 255   3   3   1   2   0]
#  [  0   4   1   0   8 181  18   3   1   0]
#  [  0   1   3   0   1   0 275   0   5   0]
#  [  0   0   1   0   0   4  16 206   0   0]
#  [  0   0   0   0   1   0  10   0 239   1]
#  [  0   0   1   0   4   2   5   1  17 166]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       300
#            1       0.95      0.92      0.94       237
#            2       0.96      0.94      0.95       252
#            3       0.94      0.95      0.95       222
#            4       0.93      0.96      0.94       265
#            5       0.95      0.84      0.89       216
#            6       0.83      0.96      0.89       285
#            7       0.97      0.91      0.94       227
#            8       0.90      0.95      0.92       251
#            9       0.99      0.85      0.91       196
#
#     accuracy                           0.93      2451
#    macro avg       0.94      0.93      0.93      2451
# weighted avg       0.93      0.93      0.93      2451

# %%
print('specificity:')
tot=0
for i in range (10):
    sum=0
    for j in range(10):
        sum=sum+cf_matrix[i,j]
    spec=cf_matrix[i,i]/sum
    tot+=spec
    print(i," ",spec)
print('specificity avg\n',tot/10)
# Out:
# specificity:
# 0   0.98
# 1   0.919831223628692
# 2   0.9444444444444444
# 3   0.9504504504504504
# 4   0.9622641509433962
# 5   0.8379629629629629
# 6   0.9649122807017544
# 7   0.9074889867841409
# 8   0.952191235059761
# 9   0.8469387755102041
# specificity avg
#  0.9266484510485805

# %%
acc_train = history.history["accuracy"]
acc_val = history.history["val_accuracy"]
epochs = range(1,99)
plt.plot(acc_train, 'g', label='Training accuracy')
plt.plot(acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss_train = history.history["loss"]
loss_val = history.history["val_loss"]
epochs = range(1,99)
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
